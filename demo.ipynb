# %%
from optimizer import Optimizer
from heuristics import * 
import random 
import numpy as np 
import pandas as pd
import random
import colorsys
from heuristics import TabuSearchScheduler

# %%
random.seed(42)
np.random.seed(42)

# %%
def generate_distinct_colors(n):
    hues = [i / n for i in range(n)]
    random.shuffle(hues)
    
    colors = []
    saturation = 0.7  # Adjust between 0 (gray) and 1 (fully saturated)
    value = 0.9       # Adjust between 0 (black) and 1 (full brightness)
    
    for h in hues:
        r, g, b = colorsys.hsv_to_rgb(h, saturation, value)
        hex_color = f'#{int(r * 255):02x}{int(g * 255):02x}{int(b * 255):02x}'
        colors.append(hex_color)
    
    return colors

# %%
def get_dynamic_parameters(num_parts, num_colors):

    print(num_parts, num_colors)

    max_time_machine_A = ( 8 * 60 * 60)
    max_time_machine_B = ( 7 * 60 * 60)

    unit_production_time = 80
    cleaning_time = 80

    machines = [1,2]

    max_times = [max_time_machine_A, max_time_machine_B]

    demand = {p: int((max_time_machine_A + max_time_machine_B) / (unit_production_time * (num_parts + num_colors))) for p in range(1, num_parts + 1)}

    for i in range(1, len(machines) + 1):
        demand[num_parts + i] = 0

    colors = generate_distinct_colors(num_colors)
    parts_colors = {i: colors[(i - 1) % len(colors)] for i in range(1, num_parts + 1)}

    alpha = [[abs(1 - (parts_colors[p] == parts_colors[q])) for q in range(1, num_parts + 1)] for p in range(1, num_parts + 1)]

    return {
        "num_parts": num_parts,
        "num_colors": num_colors,
        "max_times" : max_times,
        "demand": demand,
        "parts_colors": parts_colors,
        "alpha": alpha,
        "unit_production_time": unit_production_time,
        "cleaning_time": cleaning_time,
        "machines": machines,
    }

# %% [markdown]
# # Run Experiments

# %%
results = []

# %%
# for num_parts in [ 120,130,140,150]:  
#     for num_colors in range(1, num_parts, int(num_parts / 5)):  
#         try:
#             problem_parameters = get_dynamic_parameters(num_parts, num_colors)
#             optimizer = Optimizer(**problem_parameters)
#             model, objective_value, optimization_time = optimizer(verbose=True)
#             results.append([num_parts, num_colors, round(optimization_time, 4), objective_value])
#             results_df = pd.DataFrame(results, columns=["Number of Parts", "Number of Colors", "Time", "Objective Value"])
#             results_df.to_csv("results.csv", index=False)
#             print()
#             print()
#         except Exception as e:
#             print(e)
#             pass

# results_df

# %% [markdown]
# ## Visualize Results

# %%
problem_parameters = get_dynamic_parameters(40,9)
optimizer = Optimizer(**problem_parameters)
model, objective_value, optimization_time = optimizer(verbose=True)
optimizer.visualize()
# Out:
# 40 9
# Set parameter Username
# Set parameter LicenseID to value 2586912
# Academic license - for non-commercial use only - expires 2025-11-19
# Set parameter IntFeasTol to value 1e-09
# Set parameter Threads to value 8
# Set parameter Seed to value 12345
# Set parameter BestObjStop to value 7.5
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (mac64[arm] - Darwin 24.3.0 24D70)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# BestObjStop  7.5
# IntFeasTol  1e-09
# MIPGap  0.01
# Seed  12345
# Threads  8
#
# Optimize a model with 9484 rows, 3612 columns and 162680 nonzeros
# Model fingerprint: 0x6cebf24f
# Variable types: 84 continuous, 3528 integer (3528 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+04]
# Presolve removed 3082 rows and 332 columns
# Presolve time: 0.20s
# Presolved: 6402 rows, 3280 columns, 146960 nonzeros
# Variable types: 80 continuous, 3200 integer (3200 binary)
# Found heuristic solution: objective 38.0000000
#
# Root relaxation: objective 0.000000e+00, 284 iterations, 0.02 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0   44   38.00000    0.00000   100%     -    0s
# H    0     0                      36.0000000    0.00000   100%     -    0s
# H    0     0                      33.0000000    0.00000   100%     -    1s
#      0     0    0.00000    0   70   33.00000    0.00000   100%     -    1s
# H    0     0                      10.0000000    0.00000   100%     -    1s
#      0     0    0.00000    0   70   10.00000    0.00000   100%     -    2s
# H    0     0                       7.0000000    0.00000   100%     -    2s
#
# Cutting planes:
#   Gomory: 8
#   Cover: 1
#   Implied bound: 24
#   MIR: 40
#   StrongCG: 1
#   Zero half: 11
#   RLT: 12
#   Relax-and-lift: 8
#
# Explored 1 nodes (1314 simplex iterations) in 2.49 seconds (2.03 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 7 10 33 ... 38
#
# Optimization achieved user objective limit
# Best objective 7.000000000000e+00, best bound 0.000000000000e+00, gap 100.0000%
# Number of quadratic constraints: 0
# Number of quadratic objective terms: 0
# Model is MILP: True
